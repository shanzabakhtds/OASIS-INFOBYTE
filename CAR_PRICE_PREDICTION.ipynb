# %% [markdown]
# <a href="https://colab.research.google.com/github/shanzabakhtds/OASIS-INFOBYTE/blob/main/CAR_PRICE_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **Problem Statement:**
#
#
#
# > The goal of this project is to provide a learning opportunity for individuals interested in understanding and implementing the training of a car price prediction model.
#
# > The project aims to explore the intricacies of correlating various car attributes with their respective prices, contributing to the broader field of machine learning research in automotive valuation.

# %% [markdown]
# # **Libraries**

# %%
# for reshaping arrays and working with numerical data
import numpy as np

#used for working with datasets, offering functions for data analysis, cleaning, exploration, and manipulation
import pandas as pd

#used for pie charts for visualizing results
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Loading Dataset**

# %%
df = pd.read_csv("/content/car data.csv")

# %% [markdown]
# # **Exploring The DataSet**

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print("The Size of Dataset is=",df.size)
# Out:
# The Size of Dataset is= 2709

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.duplicated().sum()
# Out:
# 2

# %%
#lets remove duplicated data
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **Understanding the Problem**
#
#  Estimate the Sale Price of the Car by considering all **8** features as crucial factors.
#
# We will use **Random Forest Regressor** and **Decision Tree** (as a comparison) to solve this problem

# %%
print('Unique Values of Fuel Type',df['Fuel_Type'].unique())
print('Unique Values of Transmission',df['Transmission'].unique())
print('Unique Values of Selling Type',df['Selling_type'].unique())
print('Unique Values of Owner',df['Owner'].unique())
print('Unique Values of Year',df['Year'].unique())
# Out:
# Unique Values of Fuel Type ['Petrol' 'Diesel' 'CNG']
# Unique Values of Transmission ['Manual' 'Automatic']
# Unique Values of Selling Type ['Dealer' 'Individual']
# Unique Values of Owner [0 1 3]
# Unique Values of Year [2014 2013 2017 2011 2018 2015 2016 2009 2010 2012 2003 2008 2006 2005
#  2004 2007]

# %% [markdown]
# # **Visualisation of Data**

# %%
plt.figure(figsize=(15,7))
for i,col in enumerate(['Selling_Price','Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.histplot(data=df, x=col, kde=True, hue='Transmission')

# %%
plt.figure(figsize=(9,4))
sns.histplot(data=df, x=col, kde=True, hue='Selling_type')
# Out:
# <Axes: xlabel='Driven_kms', ylabel='Count'>

# %%
plt.figure(figsize=(18,9))
for i,col in enumerate(['Selling_Price','Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.boxplot(data=df, y='Fuel_Type', x=col, orient='h')

# %%
plt.figure(figsize=(17,8))
for i,col in enumerate(['Selling_Price','Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.boxplot(data=df, y='Owner', x=col, orient='h')

# %%
plt.figure(figsize=(20,8))
for i,col in enumerate(['Selling_Price','Present_Price']):
    plt.subplot(2,2,i+1)
    sns.boxplot(data=df, y='Transmission', x=col, orient='h')

# %%
plt.figure(figsize=(17,8))
for i,col in enumerate(['Selling_Price','Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.boxplot(data=df, y='Selling_type', x=col, orient='h')

# %%
plt.figure(figsize=(15,8))
color=['brown','purple','blue']
for i,col in enumerate(['Year','Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.scatterplot(df,x=col,y='Selling_Price',color=color[i])
plt.tight_layout()

# %% [markdown]
# # **Analysis:**
#
# 1. **Automatic Cars** appear to have higher present prices and selling prices, as well as higher kilometers driven, compared to manual cars.
#
# 2. **Dealer** seems to sell the car at a higher selling price than individuals.
#
# 3. **Diesel Cars** seem to have a higher price than others, while Petrol Cars seem to have a higher price than **CNG cars**.
#
#
#
#    > The data seems to contain a lot of outliers and needs to be scaled as well.
#
#
# > Latest cars seem to have higher selling price.
#
#
# > The greater the present price, the greater the selling price.
#
# > The fewer the driven kilometers, the higher the selling price.

# %% [markdown]
# #**Data Pre-processing:**

# %% [markdown]
# **Removing outliers**

# %%
def remove_outliers(col):
    d25=df[col].quantile(0.25)
    d75=df[col].quantile(0.75)
    diqr=d75-d25
    upper_lim=d75+1.5*diqr
    lower_lim=d25-1.5*diqr
    filter_data=df[ (df[col] >= lower_lim) & (df[col] <= upper_lim) ]
    return filter_data

df=remove_outliers('Selling_Price')
df=remove_outliers('Present_Price')
df=remove_outliers('Driven_kms')

# %% [markdown]
# # **Modelling:**

# %%
from sklearn.preprocessing import LabelEncoder

#hot encoding
encoder=LabelEncoder()

encoder.fit(df['Fuel_Type'])
df['Fuel_Type']=encoder.fit_transform(df['Fuel_Type'])
dictft=dict(enumerate(encoder.classes_))
print(dictft)

encoder.fit(df['Selling_type'])
df['Selling_type']=encoder.fit_transform(df['Selling_type'])
dictst=dict(enumerate(encoder.classes_))
print(dictst)

encoder.fit(df['Transmission'])
df['Transmission']=encoder.fit_transform(df['Transmission'])
dicttr=dict(enumerate(encoder.classes_))
print(dicttr)

encoder.fit(df['Car_Name'])
df['Car_Name']=encoder.fit_transform(df['Car_Name'])
dictcn=dict(enumerate(encoder.classes_))
print(dictcn)

df.head()
# Out:
# {0: 'CNG', 1: 'Diesel', 2: 'Petrol'}
# {0: 'Dealer', 1: 'Individual'}
# {0: 'Automatic', 1: 'Manual'}
# ...

# %%
X=df.drop(columns=['Selling_Price'],axis=1)
X=X.values
Y=df[['Selling_Price']].values.flatten()

X[:5,],Y[:5]
# Out:
# (array([[8.600e+01, 2.014e+03, 5.590e+00, 2.700e+04, 2.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00],
#         [8.900e+01, 2.013e+03, 9.540e+00, 4.300e+04, 1.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00],
#         [6.600e+01, 2.017e+03, 9.850e+00, 6.900e+03, 2.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00],
#         [9.200e+01, 2.011e+03, 4.150e+00, 5.200e+03, 2.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00],
#         [8.800e+01, 2.014e+03, 6.870e+00, 4.245e+04, 1.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00]]),
#  array([3.35, 4.75, 7.25, 2.85, 4.6 ]))

# %% [markdown]
# **LETS TRY MANUALLY WITH DIFFERENT NUMBER OF DECISION TREES TO FIND MODEL BEST FIT TO DATA**

# %% [markdown]
# # **Splitting Data into Training and Testing**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

mse_vals = []
r2_vals = []
min_mse = float('inf')
max_r2 = -float('inf')
min_mse_n_est = None
max_r2_n_est = None

# from 1 decision tree to 100 decision trees
for i in range(1, 101):
    rfr_model = RandomForestRegressor(n_estimators=i, random_state=42)
    rfr_model.fit(x_train, y_train)
    y_test_pred = rfr_model.predict(x_test)

    # MSE
    mse = mean_squared_error(y_test, y_test_pred)
    # R2 SCORE
    r2_sco = r2_score(y_test, y_test_pred)

    # append
    mse_vals.append(mse)
    r2_vals.append(r2_sco)

    # compare
    if mse < min_mse:
        min_mse = mse
        min_mse_n_est = i
    if r2_sco > max_r2:
        max_r2 = r2_sco
        max_r2_n_est = i

print('Minimum MSE: {} with {} estimators'.format(min_mse, min_mse_n_est))
print('Maximum R2 Score: {} with {} estimators'.format(max_r2, max_r2_n_est))
# Out:
# Minimum MSE: 0.3587487913084846 with 33 estimators
# Maximum R2 Score: 0.9661355472028293 with 33 estimators

# %% [markdown]
#  As we saw above, setting **n_estimators to 33** gives us the best value, so we can use this specific value to train our model.
#
#  However, it's just a small difference in R2 Score, but a good improvement of approximately 0.3 in MSE.

# %% [markdown]
# # **ANALYSIS OF RESULTS**

# %%
fig,ax=plt.subplots()
ax.plot(range(1,101),mse_vals,'red')
ax.set_xlabel('N-ESTIMATORS')
ax.set_ylabel('MSE')
ax2=ax.twinx()
ax2.plot(range(1,101),r2_vals,'green')
ax2.set_ylabel('R2 Score')
plt.title('N-Estimators vs MSE and R2 Score')
plt.show()

# %% [markdown]
# # **Model Development**

# %%
#model development
rfr_model=RandomForestRegressor(n_estimators=33,random_state=42)
rfr_model.fit(x_train,y_train)
y_test_pred=rfr_model.predict(x_test)

#MSE
mse=mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error: ",mse)

#R2 SCORE
r2_sco=r2_score(y_test, y_test_pred)
print("R2 Score: ",r2_sco)
# Out:
# Mean Squared Error:  0.3587487913084846
# R2 Score:  0.9661355472028293

# %% [markdown]
# # **Output vs Predicted**

# %%
fig=plt.figure(figsize=(14,4))
sns.regplot(x=y_test,y=y_test_pred,color='purple')
plt.title('Actual vs Predicted Selling Price')
plt.xlabel('Actual Test Values')
plt.ylabel('Predicted Test Values')
# Out:
# Text(0, 0.5, 'Predicted Test Values')

# %% [markdown]
# # AS PER PLOT ABOVE, THE MODEL RESULTS SEEM SATISFACTORY

# %% [markdown]
# # **IMPORTANCE OF FEATURES**

# %%
feature_imps=pd.Series(rfr_model.feature_importances_,index=['Car_Name','Year','Present_Price','Driven_kms','Fuel_Type','Selling_type','Transmission','Owner'])
plt.figure(figsize=(10,8))
feature_imps.plot(kind='barh')
plt.ylabel('Features')
plt.xlabel('Importances')
plt.title('Feature Importances as per the Model/Random Forest Regressor')
plt.show()

# %% [markdown]
# # **Another Model - Decision Tree as a Comparison**

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

dt_model=DecisionTreeRegressor(random_state=42)
dt_model.fit(x_train,y_train)
y_test_pred=dt_model.predict(x_test)

#MSE
mse=mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error: ",mse)

#R2 SCORE
r2_sco=r2_score(y_test, y_test_pred)
print("R2 Score: ",r2_sco)
# Out:
# Mean Squared Error:  0.5091734939759035
# R2 Score:  0.9519360561761713

# %% [markdown]
# # **Comparison Result**
# As observed earlier, the **Random Forest Regressor** provided:
# > **Mean Squared Error:**  0.3587487913084846 <br>
#
#
# > **R2 Score:**    0.9661355472028293 <br><br>
#
#
#
# In contrast, the **Decision Tree Regressor** yielded:
#
#
# > **Mean Squared Error:**  0.5091734939759035 <br>
#
#
# > **R2 Score:**    0.9519360561761713 <br><br>
#
#
# **So, our 1st choice, *the Random Forest Regressor*, was better!**
#
# It had **less error** and **a** **higher $R^2$  score** compared to the Decision Tree Regressor.
